# %%
import requests
import pandas as pd
import time
from tqdm import tqdm

# 1. Set your Rijksmuseum API Key
RIJKSMUSEUM_API_KEY = "otcPObCt"

# 2. Define the API endpoint
RIJKSMUSEUM_ENDPOINT = "https://www.rijksmuseum.nl/api/en/collection"

# 3. Define a function to search artworks
def search_rijksmuseum(query, max_items=20, theme=None):
    params = {
        "key": RIJKSMUSEUM_API_KEY,
        "format": "json",
        "q": query,
        "ps": 100  # page size (max 100)
    }
    response = requests.get(RIJKSMUSEUM_ENDPOINT, params=params)
    response.raise_for_status()
    data = response.json()
    artworks = []
    
    for art_obj in tqdm(data.get('artObjects', [])[:max_items]):
        artwork = {
            "id": art_obj.get("objectNumber"),
            "title": art_obj.get("title"),
            "artist": art_obj.get("principalOrFirstMaker"),
            "longTitle": art_obj.get("longTitle"),
            "image_url": art_obj.get("webImage", {}).get("url", None),
            "theme": theme,
            "description": None  # placeholder for curator description
        }
        artworks.append(artwork)
    
    return artworks

# 4. Function to fetch detailed description (if available)
def fetch_artwork_details(object_number):
    details_url = f"https://www.rijksmuseum.nl/api/en/collection/{object_number}"
    params = {
        "key": RIJKSMUSEUM_API_KEY,
        "format": "json",
    }
    response = requests.get(details_url, params=params)
    response.raise_for_status()
    data = response.json()
    
    description = data.get('artObject', {}).get('label', {}).get('description', None)
    return description

# 5. Collect artworks across different themes
themes = ["landscape", "animals", "history", "still life", "mythology"]
artworks = []

for theme in themes:
    print(f"Fetching artworks for theme: {theme}")
    themed_artworks = search_rijksmuseum(theme, max_items=6, theme=theme)  # fetch a few extra in case some are filtered out
    artworks.extend(themed_artworks)
    time.sleep(1)

# 6. Fetch detailed descriptions if available
for art in tqdm(artworks):
    if art['id']:
        try:
            desc = fetch_artwork_details(art['id'])
            art['description'] = desc
            time.sleep(0.5)
        except Exception as e:
            print(f"Failed to fetch details for {art['id']}: {e}")

# 7. Filter artworks with missing descriptions
artworks = [art for art in artworks if art['description'] is not None]
print(f"Final number of artworks with descriptions: {len(artworks)}")

# 8. Convert to DataFrame
df = pd.DataFrame(artworks)

# 9. Save to JSON
df.to_json("data/real_museum_metadata.json", orient="records", indent=4)

print("Successfully saved to 'data/real_museum_metadata.json'")
print(df)
# Out:
# Fetching artworks for theme: landscape
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 64527.75it/s]
# Fetching artworks for theme: animals
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 57065.36it/s]
# Fetching artworks for theme: history
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 39260.26it/s]
# Fetching artworks for theme: still life
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 52103.16it/s]
# Fetching artworks for theme: mythology
# 100%|██████████████████████████████████████████| 6/6 [00:00<00:00, 39199.10it/s]
# 100%|███████████████████████████████████████████| 30/30 [00:39<00:00,  1.32s/it]
# Final number of artworks with descriptions: 23
# Successfully saved to 'data/real_museum_metadata.json'
#                 id                                              title  \
# 0        SK-A-1718                  Winter Landscape with Ice Skaters
# 1        SK-A-4688              Italian Landscape with Umbrella Pines
# 2         SK-C-109               Italian Landscape with a Draughtsman
# 3        SK-A-4118                        River Landscape with Riders
# 4         SK-A-133  Portrait of a Married Couple, Likely Isaac Abr...
# 5        SK-A-1505  A Windmill on a Polder Waterway, Known as ‘In ...
# 6         BK-17496                                        Blue Parrot
# 7         SK-A-175  A Pelican and other Birds near a Pool, Known a...
# 8       BK-1963-64                           Wine fountain and cooler
# 9        SK-A-1115                             The Battle of Waterloo
# 10      BK-17040-A                                     Table ornament
# 11      BK-1976-75                                        Lidded ewer
# 12       SK-A-4688              Italian Landscape with Umbrella Pines
# 13      BK-NM-1315                                Stadtholder’s chair
# 14       SK-A-4100          The Art Gallery of Jan Gildemeester Jansz
# 15        BK-15613                        Haarlem reception room 1794
# 16      BK-17040-A                                     Table ornament
# 17        SK-A-799                                  Floral Still Life
# 18       SK-A-2099                          Still Life with Asparagus
# 19       SK-A-4830                         Still Life with a Gilt Cup
# 20       SK-A-4821                             Still Life with Cheese
# 21        BK-16676                                               Desk
# 22  RP-P-1911-3288  Animals and Attributes from Chinese and Japane...
#
#                             artist  \
# 0                Hendrick Avercamp
# 1                    Hendrik Voogd
# 2                         Jan Both
# 3                     Aelbert Cuyp
# 4                       Frans Hals
# 5   Paul Joseph Constantin Gabriël
# 6   Meissener Porzellan Manufaktur
# 7           Melchior d'Hondecoeter
# 8                     Alger Mensma
# 9              Jan Willem Pieneman
# 10                Wenzel Jamnitzer
# 11             Adam van Vianen (I)
# 12                   Hendrik Voogd
# 13                    Gerrit Hutte
# 14                Adriaan de Lelie
# 15            Abraham van der Hart
# 16                Wenzel Jamnitzer
# 17                 Hans Bollongier
# 18                  Adriaen Coorte
# 19              Willem Claesz Heda
# 20         Floris Claesz van Dijck
# 21                Abraham Roentgen
# 22                  Bernard Picart
#
#                                             longTitle  \
# 0   Winter Landscape with Ice Skaters, Hendrick Av...
# 1   Italian Landscape with Umbrella Pines, Hendrik...
# 2   Italian Landscape with a Draughtsman, Jan Both...
# 3   River Landscape with Riders, Aelbert Cuyp, c. ...
# 4   Portrait of a Married Couple, Likely Isaac Abr...
# 5   A Windmill on a Polder Waterway, Known as ‘In ...
# 6   Blue Parrot, Meissener Porzellan Manufaktur, 1731
# 7   A Pelican and other Birds near a Pool, Known a...
# 8   Wine fountain and cooler, Alger Mensma (attrib...
# 9   The Battle of Waterloo, Jan Willem Pieneman, 1824
# 10             Table ornament, Wenzel Jamnitzer, 1549
# 11             Lidded ewer, Adam van Vianen (I), 1614
# 12  Italian Landscape with Umbrella Pines, Hendrik...
# 13            Stadtholder’s chair, Gerrit Hutte, 1747
# 14  The Art Gallery of Jan Gildemeester Jansz, Adr...
# 15  Haarlem reception room 1794, Abraham van der H...
# 16             Table ornament, Wenzel Jamnitzer, 1549
# 17           Floral Still Life, Hans Bollongier, 1639
# 18    Still Life with Asparagus, Adriaen Coorte, 1697
# 19  Still Life with a Gilt Cup, Willem Claesz Heda...
# 20  Still Life with Cheese, Floris Claesz van Dijc...
# 21          Desk, Abraham Roentgen, c. 1758 - c. 1760
# 22  Animals and Attributes from Chinese and Japane...
#
#                                             image_url       theme  \
# 0   https://lh3.googleusercontent.com/1pTfYJlLwVTi...   landscape
# 1   https://lh3.googleusercontent.com/aqXgCqxvgXIt...   landscape
# 2   https://lh3.googleusercontent.com/KA2hIo0BlMDm...   landscape
# 3   https://lh3.googleusercontent.com/X7_CHCjksOZY...   landscape
# 4   https://lh3.googleusercontent.com/yfH3HoYjUOOX...   landscape
# 5   https://lh3.googleusercontent.com/nfJiRConmXf4...   landscape
# 6   https://lh3.ggpht.com/5sc-SGzzgobkHnmnykUi4B1P...     animals
# 7   https://lh3.googleusercontent.com/3UIOtn2DLhEC...     animals
# 8   https://lh5.ggpht.com/PF93ZLrsXKoUzyv5MGg1cgid...     animals
# 9   https://lh3.googleusercontent.com/MHkVLylkz-IT...     animals
# 10  https://lh6.ggpht.com/9ulJVSDjPC6uiOPm-0Lj44ci...     animals
# 11  https://lh3.googleusercontent.com/Ovyo5Lk0AJGQ...     animals
# 12  https://lh3.googleusercontent.com/aqXgCqxvgXIt...     history
# 13  https://lh5.ggpht.com/xsp3XhQMxPi-eR9q6_Th3MIE...     history
# 14  https://lh3.googleusercontent.com/vkoS9jmZLZWu...     history
# 15  https://lh6.ggpht.com/d8aPf4-PukU3BjWLFVXjqFcQ...     history
# 16  https://lh6.ggpht.com/9ulJVSDjPC6uiOPm-0Lj44ci...     history
# 17  https://lh3.googleusercontent.com/nAGClUPzsX6A...  still life
# 18  https://lh3.googleusercontent.com/qEnlrp5MyHgL...  still life
# 19  https://lh3.googleusercontent.com/mZj-trnVh6je...  still life
# 20  https://lh3.googleusercontent.com/O6IfrxhVOGXd...  still life
# 21  https://lh4.ggpht.com/FeheHnW8-KOx-prHRCvly8Re...  still life
# 22  https://lh4.ggpht.com/TmXFjM8Q_pmyZCYbePZmeWJo...   mythology
#
#                                           description
# 0   The high vantage point of this painting turns ...
# 1   Voogd was known as the ‘Dutch Claude’, after t...
# 2   Our eye meanders happily through this large pa...
# 3   This is a panoramic, sun-drenched river landsc...
# 4   It was rare for a married couple to be portray...
# 5   ‘Our country is saturated with colour. ... I r...
# 6   This parrot perches momentarily on a tree stum...
# 7   It must have been a great honour for Hondecoet...
# 8   The wine fountain and the cooler, used to rins...
# 9   Here the Duke of Wellington is receiving the m...
# 10  This table ornament is an ode to the Earth and...
# 11  On this ewer everything is in motion. Animal a...
# 12  Voogd was known as the ‘Dutch Claude’, after t...
# 13  This chair was used by William IV when he pres...
# 14  In 1792, the merchant Gildemeester converted t...
# 15  This room was built and furnished for Willem P...
# 16  This table ornament is an ode to the Earth and...
# 17  This exuberant bouquet may look natural, but t...
# 18  Coorte produced mostly small, intimate still l...
# 19  The range of grey tonalities that Willem Heda ...
# 20  Fruit, bread, and cheese – grouped by type – a...
# 21  This desk has numerous hidden compartments and...
# 22  Here Picart illustrated Chinese and Japanese v...

# %%
print(df)
# Out:
#                id                                              title  \
# 0       SK-A-1718                  Winter Landscape with Ice Skaters
# 1       SK-A-4688              Italian Landscape with Umbrella Pines
# 2        SK-C-109               Italian Landscape with a Draughtsman
# 3       SK-A-4118                        River Landscape with Riders
# 4        BK-17496                                        Blue Parrot
# 5        SK-A-175  A Pelican and other Birds near a Pool, Known a...
# 6      BK-1963-64                           Wine fountain and cooler
# 7       SK-A-1115                             The Battle of Waterloo
# 8       SK-A-4688              Italian Landscape with Umbrella Pines
# 9      BK-NM-1315                                Stadtholder’s chair
# 10      SK-A-1451  The Well-stocked Kitchen, with Jesus in het Ho...
# 11      SK-A-4100          The Art Gallery of Jan Gildemeester Jansz
# 12       SK-A-799                                  Floral Still Life
# 13      SK-A-2099                          Still Life with Asparagus
# 14      SK-A-4830                         Still Life with a Gilt Cup
# 15      SK-A-4821                             Still Life with Cheese
# 16  BK-NM-14058-A                      Cup with a mythological scene
# 17   AK-RBK-14729       Dish with mythological animals in landscapes
# 18    AK-NM-13508          Plate with a mythological image of Cybele
# 19   AK-RBK-15878  Sleeve Vase Decorated with Birds and Flowering...
#
#                             artist  \
# 0                Hendrick Avercamp
# 1                    Hendrik Voogd
# 2                         Jan Both
# 3                     Aelbert Cuyp
# 4   Meissener Porzellan Manufaktur
# 5           Melchior d'Hondecoeter
# 6                     Alger Mensma
# 7              Jan Willem Pieneman
# 8                    Hendrik Voogd
# 9                     Gerrit Hutte
# 10              Joachim Bueckelaer
# 11                Adriaan de Lelie
# 12                 Hans Bollongier
# 13                  Adriaen Coorte
# 14              Willem Claesz Heda
# 15         Floris Claesz van Dijck
# 16                       anonymous
# 17                       anonymous
# 18                       anonymous
# 19                       anonymous
#
#                                             longTitle  \
# 0   Winter Landscape with Ice Skaters, Hendrick Av...
# 1   Italian Landscape with Umbrella Pines, Hendrik...
# 2   Italian Landscape with a Draughtsman, Jan Both...
# 3   River Landscape with Riders, Aelbert Cuyp, c. ...
# 4   Blue Parrot, Meissener Porzellan Manufaktur, 1731
# 5   A Pelican and other Birds near a Pool, Known a...
# 6   Wine fountain and cooler, Alger Mensma (attrib...
# 7   The Battle of Waterloo, Jan Willem Pieneman, 1824
# 8   Italian Landscape with Umbrella Pines, Hendrik...
# 9             Stadtholder’s chair, Gerrit Hutte, 1747
# 10  The Well-stocked Kitchen, with Jesus in het Ho...
# 11  The Art Gallery of Jan Gildemeester Jansz, Adr...
# 12           Floral Still Life, Hans Bollongier, 1639
# 13    Still Life with Asparagus, Adriaen Coorte, 1697
# 14  Still Life with a Gilt Cup, Willem Claesz Heda...
# 15  Still Life with Cheese, Floris Claesz van Dijc...
# 16  Cup with a mythological scene, anonymous, c. 1...
# 17  Dish with mythological animals in landscapes, ...
# 18  Plate with a mythological image of Cybele, ano...
# 19  Sleeve Vase Decorated with Birds and Flowering...
#
#                                             image_url       theme  \
# 0   https://lh3.googleusercontent.com/1pTfYJlLwVTi...   landscape
# 1   https://lh3.googleusercontent.com/aqXgCqxvgXIt...   landscape
# 2   https://lh3.googleusercontent.com/KA2hIo0BlMDm...   landscape
# 3   https://lh3.googleusercontent.com/X7_CHCjksOZY...   landscape
# 4   https://lh3.ggpht.com/5sc-SGzzgobkHnmnykUi4B1P...     animals
# 5   https://lh3.googleusercontent.com/3UIOtn2DLhEC...     animals
# 6   https://lh5.ggpht.com/PF93ZLrsXKoUzyv5MGg1cgid...     animals
# 7   https://lh3.googleusercontent.com/MHkVLylkz-IT...     animals
# 8   https://lh3.googleusercontent.com/aqXgCqxvgXIt...     history
# 9   https://lh5.ggpht.com/xsp3XhQMxPi-eR9q6_Th3MIE...     history
# 10  https://lh3.googleusercontent.com/SjuKgVllMl-w...     history
# 11  https://lh3.googleusercontent.com/vkoS9jmZLZWu...     history
# 12  https://lh3.googleusercontent.com/nAGClUPzsX6A...  still life
# 13  https://lh3.googleusercontent.com/qEnlrp5MyHgL...  still life
# 14  https://lh3.googleusercontent.com/mZj-trnVh6je...  still life
# 15  https://lh3.googleusercontent.com/O6IfrxhVOGXd...  still life
# 16  https://lh3.googleusercontent.com/3Pt1MkwK4NQx...   mythology
# 17  https://lh3.googleusercontent.com/JduxCL1TNDG2...   mythology
# 18  https://lh3.ggpht.com/xTb2AV9v27nylOjpTkP-rjSO...   mythology
# 19  https://lh3.googleusercontent.com/VrgkmwiKIMmJ...   mythology
#
#                                           description
# 0   The high vantage point of this painting turns ...
# 1   Voogd was known as the ‘Dutch Claude’, after t...
# 2   Our eye meanders happily through this large pa...
# 3   This is a panoramic, sun-drenched river landsc...
# 4   This parrot perches momentarily on a tree stum...
# 5   It must have been a great honour for Hondecoet...
# 6   The wine fountain and the cooler, used to rins...
# 7   Here the Duke of Wellington is receiving the m...
# 8   Voogd was known as the ‘Dutch Claude’, after t...
# 9   This chair was used by William IV when he pres...
# 10                                               None
# 11  In 1792, the merchant Gildemeester converted t...
# 12  This exuberant bouquet may look natural, but t...
# 13  Coorte produced mostly small, intimate still l...
# 14  The range of grey tonalities that Willem Heda ...
# 15  Fruit, bread, and cheese – grouped by type – a...
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
